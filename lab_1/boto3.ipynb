# %%
# !conda install boto3 -y
# Out:
# Channels:
#  - defaults
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /workspaces/boto3/.conda
#
#   added / updated specs:
#     - boto3
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     boto3-1.34.82              |  py310h06a4308_0         130 KB
#     botocore-1.34.82           |  py310h06a4308_0         7.2 MB
#     brotli-python-1.0.9        |  py310h6a678d5_8         356 KB
#     jmespath-1.0.1             |  py310h06a4308_0          38 KB
#     pysocks-1.7.1              |  py310h06a4308_0          28 KB
#     python-dateutil-2.9.0post0 |  py310h06a4308_2         280 KB
#     s3transfer-0.10.1          |  py310h06a4308_0         115 KB
#     six-1.16.0                 |     pyhd3eb1b0_1          18 KB
#     urllib3-2.2.2              |  py310h06a4308_0         179 KB
#     ------------------------------------------------------------
#                                            Total:         8.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   boto3              pkgs/main/linux-64::boto3-1.34.82-py310h06a4308_0
#   botocore           pkgs/main/linux-64::botocore-1.34.82-py310h06a4308_0
#   brotli-python      pkgs/main/linux-64::brotli-python-1.0.9-py310h6a678d5_8
#   jmespath           pkgs/main/linux-64::jmespath-1.0.1-py310h06a4308_0
#   pysocks            pkgs/main/linux-64::pysocks-1.7.1-py310h06a4308_0
#   python-dateutil    pkgs/main/linux-64::python-dateutil-2.9.0post0-py310h06a4308_2
#   s3transfer         pkgs/main/linux-64::s3transfer-0.10.1-py310h06a4308_0
#   six                pkgs/main/noarch::six-1.16.0-pyhd3eb1b0_1
#   urllib3            pkgs/main/linux-64::urllib3-2.2.2-py310h06a4308_0
#
#
#
# Downloading and Extracting Packages:
# botocore-1.34.82     | 7.2 MB    |                                       |   0%
# brotli-python-1.0.9  | 356 KB    |                                       |   0%
#
# python-dateutil-2.9. | 280 KB    |                                       |   0%
#
#
# urllib3-2.2.2        | 179 KB    |                                       |   0%
#
#
#
# boto3-1.34.82        | 130 KB    |                                       |   0%
#
#
#
#
# s3transfer-0.10.1    | 115 KB    |                                       |   0%
#
#
#
#
#
# jmespath-1.0.1       | 38 KB     |                                       |   0%
#
#
#
#
#
#
# pysocks-1.7.1        | 28 KB     |                                       |   0%
#
#
#
#
#
#
#
# six-1.16.0           | 18 KB     |                                       |   0%
# brotli-python-1.0.9  | 356 KB    | #6                                    |   4%
#
#
# urllib3-2.2.2        | 179 KB    | ###3                                  |   9%
#
# python-dateutil-2.9. | 280 KB    | ##1                                   |   6%
#
#
#
# boto3-1.34.82        | 130 KB    | ####5                                 |  12%
#
#
#
#
#
# botocore-1.34.82     | 7.2 MB    |                                       |   0%
#
#
#
#
# s3transfer-0.10.1    | 115 KB    | #####1                                |  14%
# brotli-python-1.0.9  | 356 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# six-1.16.0           | 18 KB     | ################################      |  87%
#
#
#
#
#
#
# pysocks-1.7.1        | 28 KB     | ####################9                 |  57%
#
#
# urllib3-2.2.2        | 179 KB    | ##################################### | 100%
#
# python-dateutil-2.9. | 280 KB    | ##################################### | 100%
#
#
# urllib3-2.2.2        | 179 KB    | ##################################### | 100%
#
# botocore-1.34.82     | 7.2 MB    | ###########################3          |  74%
#
#
#
#
#
# jmespath-1.0.1       | 38 KB     | ##################################### | 100%
#
#
#
#
#
# jmespath-1.0.1       | 38 KB     | ##################################### | 100%
#
#
#
# boto3-1.34.82        | 130 KB    | ##################################### | 100%
#
#
#
# boto3-1.34.82        | 130 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# six-1.16.0           | 18 KB     | ##################################### | 100%
#
#
#
#
# s3transfer-0.10.1    | 115 KB    | ##################################### | 100%
#
#
#
#
# s3transfer-0.10.1    | 115 KB    | ##################################### | 100%
#
#
#
#
#
#
# pysocks-1.7.1        | 28 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
import configparser
import boto3

# Load AWS credentials from the configuration file
config = configparser.ConfigParser()
config.read('../aws.cfg')

aws_access_key = config['AWS']['aws_access_key_id']
aws_secret_key = config['AWS']['aws_secret_access_key']

# Initialize the S3 client
s3 = boto3.client(
    's3',
    aws_access_key_id=aws_access_key,
    aws_secret_access_key=aws_secret_key
)

# Verify the client is set up correctly by listing buckets
response = s3.list_buckets()
print('Existing buckets:')
for bucket in response['Buckets']:
    print(f'  {bucket["Name"]}')
# Out:
# Existing buckets:
#   alina-techcatalyst-bucket
#   amsu-aws-s3-assessment
#   amsu-s3-cf-website
#   andrea-lm-code-bucket
#   andy-techcatalyst-client
#   apiproject-build-bucket-su05297
#   aryan-techcatalyst-lab
#   austin-lambda-s3
#   aws-athena-query-results-535146832369-us-east-1
#   aws-athena-query-results-535146832369-us-west-2
#   aws-athena-query-results-us-east-1-535146832369
#   aws-athena-query-results-us-east-1-535146832369nh
#   aws-athena-query-results-us-east-1-tarek
#   aws-athena-query-results-us-east-2-535146832369
#   aws-athena-query-results-us-east-2-535146832369-kb
#   aws-athena-query-results-us-east-2-535146832369ab
#   aws-athena-query-results-us-east-2-nsp
#   aws-athena-query-results-us-east-2-sp
#   aws-cloudtrail-logs-535146832369-01f575cd
#   aws-cloudtrail-logs-535146832369-9d19bcae
#   aws-glue-assets-535146832369-us-east-1
#   aws-glue-assets-535146832369-us-east-2
#   aws-logs-535146832369-us-east-1
#   aws-sam-cli-managed-default-samclisourcebucket-1oz2tqbsdli3
#   aws-sam-cli-managed-default-samclisourcebucket-mgdplk7mifi7
#   aws-sam-cli-managed-default-samclisourcebucket-t2x2wb9il3p1
#   aws-sam-cli-managed-default-samclisourcebucket-yh6y67cvomwp
#   axel-di-student14
#   axel-di-student2
#   axel-di-student25
#   axel-di-student8
#   axel-di-team2
#   barb-lm-code-bucket
#   ben-techcatalyst-lab
#   bored-api-reactjs-build-bucket-rx08052
#   bored-api-rx08052
#   brian-s3-demo
#   bryantbeach-original-images
#   bryantbeach-thumbnail-images
#   bucket-cl05355
#   bucket-terraform-lab4-41091
#   bucket-terraform-lab4-67147
#   bucket-terraform-lab4-82140
#   bucket-terraform-lab4-95407
#   bucket-terraform-lab4-98294
#   buggy-535146832369-us-east-1
#   bugs-app-stack-535146832369-us-east-2
#   calvin-lm-code-bucket
#   capstone-cloud-template-bucket
#   capstone-service-image
#   catapiplzwork-cl05355
#   cf-templates-6dazn7owsddb-ap-south-1
#   cf-templates-6dazn7owsddb-us-east-1
#   cf-templates-6dazn7owsddb-us-east-2
#   cf-templates-6dazn7owsddb-us-west-2
#   codepipeline-us-east-2-68716816310
#   connor-awsassignment
#   connor-lambda-s3
#   connor-s3-cf-final-website
#   connor-s3-sqs
#   connorsbucketdemo
#   countingbucket-0
#   countingbucket-1
#   countingbucket-2
#   craig-lm-code-bucket
#   darrell-assessment-s3
#   david-s3-angular-assesment
#   davidprivatebucket
#   ddd434278923423
#   demo-my-build-bucket-maaike
#   devint-2373
#   devint-4633
#   devint-6326
#   devint-8987
#   devint-auser1
#   devint-auser2
#   devint-dan2238
#   devint-krueger-alt
#   devint-std14-20220329062534398200000001
#   devint-std14-20220329062534458500000001
#   devint-std14-alt
#   devint-std17-20220329063555600900000001
#   devint-std17-20220329063555696700000001
#   devint-std17-alt
#   devint-std18-20220329063643571000000001
#   devint-std18-20220329063644010600000001
#   devint-std30-20220329110905171700000001
#   devint-std4-alt
#   devint-std7-alt
#   devint-std8-20220329064413559800000001
#   devint-std8-20220329064414038300000001
#   devint-student1-2515
#   devint-student1-4241
#   devint-student10-2515
#   devint-student10-4241
#   devint-student11-2515
#   devint-student11-4241
#   devint-student12-2515
#   devint-student12-4241
#   devint-student13-2515
#   devint-student13-4241
#   devint-student14
#   devint-student14-2515
#   devint-student14-4241
#   devint-student15-2515
#   devint-student15-4241
#   devint-student16-2515
#   devint-student16-4241
#   devint-student17-2515
#   devint-student17-4241
#   devint-student18-2515
#   devint-student18-4241
#   devint-student19-2515
#   devint-student19-4241
#   devint-student2-2515
#   devint-student2-4241
#   devint-student20
#   devint-student20-2515
#   devint-student20-4241
#   devint-student21-2515
#   devint-student21-4241
#   devint-student22
#   devint-student22-2515
#   devint-student22-4241
#   devint-student23-2515
#   devint-student23-4241
#   devint-student24-2515
#   devint-student24-4241
#   devint-student25-2515
#   devint-student3-2515
#   devint-student3-4241
#   devint-student4-2515
#   devint-student4-4241
#   devint-student5-2515
#   devint-student5-4241
#   devint-student6-2515
#   devint-student6-4241
#   devint-student7-2515
#   devint-student7-4241
#   devint-student8-2515
#   devint-student8-4241
#   devint-student9
#   devint-student9-2515
#   devint-student9-4241
#   devint-tabrej-alam-alt
#   digitalnomads
#   dooku2
#   dspera-lm-code-bucket
#   dws-di-corleone
#   dws-di-dooku-20220107144313147600000001
#   dws-di-jocker
#   dws-di-krueger
#   dws-di-nosferatu
#   dws-di-nosferatu-alt
#   dws-di-ramkumar
#   dws-di-spike
#   dws-di-student10
#   dws-di-tabrej-alam
#   dws-kattegat-ragnar
#   eamonn-test-bucket-865
#   eksworkshop-535146832369-codepipeline-artifacts
#   elasticbeanstalk-us-east-1-535146832369
#   elasticbeanstalk-us-east-2-535146832369
#   eoanifoeanfeionfiobvnuem
#   ferfybucket-assessment
#   first-bucket-es05260
#   first-web-app-bucket
#   first-web-app-cs08090
#   georgethomas-original-images
#   georgethomas-thumbnail-images
#   gina-techcatalyst-lab
#   hark-assessment-bucket
#   hk-lambda-bucket
#   jalaunsbucket
#   jalaunsbucket-for-codedeploy
#   jamesbrett-lm-code-bucket
#   jc-bucket-lab
#   joe-lm-code-bucket
#   jokes-build-bucket-su05297
#   jokesbucket-su05297
#   jonathanbardwellsbucket
#   jrrickerson-demo-cohort7
#   juliev1-bucket
#   kaitlyn-techcatalyst-lab
#   kanye-build-bucket-mk05255
#   kanye-rest-bucket-mk05255
#   kerim-test-bucket
#   lab-two
#   lcates-original-images
#   lcates-thumbnail-images
#   lincoln-bucket-01
#   maaike-web-bucket
#   magesh-angular-gitlab-app
#   magesh-lambda-s3
#   malcolm-assesment-bucket
#   malcolm-sam-app-ec2-535146832369-us-east-2
#   mchase-s3
#   mini-api-project-auto-deploy-je05425
#   mini-api-project-je
#   mini-project-bucket-es05260
#   mini-react-project-cs08090
#   my-api-build-bucket-et05298
#   my-api-project-bucket-kl08053
#   my-api-project-bucket-se05269
#   my-bucket-ds08057
#   my-bucket-kl08053
#   my-bucket2-et05298
#   my-build-bucket-cl05355
#   my-build-bucket-cs08090
#   my-build-bucket-ds08057
#   my-build-bucket-es05260
#   my-build-bucket-et05298
#   my-build-bucket-jalaun
#   my-build-bucket-je05425
#   my-build-bucket-kl08053
#   my-build-bucket-maaike
#   my-build-bucket-mk05255
#   my-build-bucket-ov05296
#   my-build-bucket-rx08052
#   my-build-bucket-se05269
#   my-build-bucket-sh03945
#   my-build-bucket-su05297
#   my-project-bucket-ov05296
#   my-react-build-api-bucket-se05269
#   my-riddles-build-bucket-ov05296
#   my-s3-bucket-se05269
#   my-test-bucket-student20
#   my-tf-test-bucket-student17
#   my-tf-test-bucket-student20
#   my-tf-test-bucket-student23
#   my-tf-test-bucket-teacher2
#   myawsbucket-ds08057
#   myawsbucket-kl08053
#   myawsbucket-mini-project-ds08057
#   mybucket4efs.com
#   mybucket7707
#   mys3bucket-mk05255
#   natali-assessment-bucket
#   nithila-techcatalyst-lab
#   nsp-bucket-raw
#   nsp-bucket-transformed
#   nullwpstage
#   orion-capstone
#   patrickmccardy-lm-code-bucket
#   peter-a-week6
#   pokebucket-cs08090
#   radar-app-dev-build-bucket
#   react-jokesapi-ds08057
#   reportbucketnff1
#   repurposed-jalaunsbucket
#   rjp-original-images
#   rjp-thumbnail-images
#   rx08052-web-bucket
#   sagemaker-course-di
#   sagemaker-studio-535146832369-db81fj1x82w
#   sagemaker-us-east-1-535146832369
#   sai-tf-test-bucket-sai
#   samee-techcatalyst-lab
#   se-bucket-100
#   seatownbucket88
#   sriya-pat-bucket-2-raw
#   sriya-pat-bucket-2-transformed
#   student-6-alternate
#   student-6-main
#   student17-terraform-provisioners-example
#   student22-ex06
#   su05297-web-bucket
#   super-unique-terraform-bucket
#   tatwan-techcatalyst-lab
#   teacher2-terraform-provisioners-example
#   techcatalyst-labs
#   techcatalyst-public
#   techcatalyst-raw
#   techcatalyst-target
#   techcatalyst-transformed
#   techcatalyst-transformed-glue
#   terraform-di-student17
#   terraform-di-student17-alternate
#   terraform-lab5--42433
#   terraform-lab5--63647
#   terraform-lab5--64023
#   terraform-lab5--76528
#   terraform-lab5--92518
#   terraform-lab5--95453
#   test-connect-sh03945
#   thisisatestbucket123452439
#   tlopresti-lm-code-bucket
#   troy-aws-assessment-bucket
#   vlh-student2
#   vlh-student2-us-east-2
#   will-assessment-bucket
#   will-lambda-s3
#   will-lm-code-bucket
#   wramey-lm-code-bucket
#   zayd-public

# %%
# create bucket in us-east-1
s3.create_bucket(Bucket='ben-techcatalyst-lab')
# Out:
# {'ResponseMetadata': {'RequestId': 'XVK1WBT1S92NKHPY',
#   'HostId': 'lU5SBxmIlPuG1cgmSmZT4iBvORr7tJEhuPTHM7N0PwawdpxYhlOHfBMg1WxmNoa5cQCVVSG30yk=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'lU5SBxmIlPuG1cgmSmZT4iBvORr7tJEhuPTHM7N0PwawdpxYhlOHfBMg1WxmNoa5cQCVVSG30yk=',
#    'x-amz-request-id': 'XVK1WBT1S92NKHPY',
#    'date': 'Mon, 22 Jul 2024 16:03:11 GMT',
#    'location': '/ben-techcatalyst-lab',
#    'server': 'AmazonS3',
#    'content-length': '0'},
#   'RetryAttempts': 0},
#  'Location': '/ben-techcatalyst-lab'}

# %% [markdown]
# ### Task 2 Upload a File to S3 Using upload_fileobj

# %%
# Define the file to upload and the target bucket and key
filename = 'upload/snowflake_logo.png'  # Replace with your file path
bucket_name = 'ben-techcatalyst-lab'  # Replace with your bucket name
key = 'snowflake_logo.png'  # Replace with your file key in S3

# Upload the file to S3
with open(filename, 'rb') as file_obj:
    s3.upload_fileobj(file_obj, bucket_name, key)

# Print a confirmation message
print(f'File {filename} uploaded to bucket {bucket_name} with key {key}.')
# Out:
# File upload/snowflake_logo.png uploaded to bucket ben-techcatalyst-lab with key snowflake_logo.png.

# %% [markdown]
# ### Task 3: Upload a File to S3 Using put_object

# %%
# Define the file to upload and the target bucket and key
bucket_name = 'ben-techcatalyst-lab'  # Replace with your bucket name
key = 'customers.csv'  # Replace with your file key in S3
filename = 'upload/customers.csv'

# Upload the file to S3 using put_object
with open(filename, 'rb') as file:
    s3.put_object(Body=file, Bucket=bucket_name, Key=key)

# Print a confirmation message
print(f'File uploaded to bucket {bucket_name} with key {key}.')
# Out:
# File uploaded to bucket ben-techcatalyst-lab with key customers.csv.

# %% [markdown]
# ### Task 4: Download a File from S3 Using download_file

# %%
# Define the file to download and the target local path

bucket_name = 'ben-techcatalyst-lab'
key = 'customers.csv'  
filename = 'download/customers.csv'
# Download the file from S3
s3.download_file(bucket_name, key, filename)

# Print a confirmation message
print(f'File {key} downloaded from bucket {bucket_name} to {filename}.')
# Out:
# File customers.csv downloaded from bucket ben-techcatalyst-lab to download/customers.csv.

# %% [markdown]
# ### Task 5: Download a File from S3 Using download_fileobj

# %%
# Define the file to download and the target local path
bucket_name = 'ben-techcatalyst-lab'
key =  'snowflake_logo.png'
filename = 'download/snowflake_logo.png'

# Download the file from S3 using file-like object
s3.download_file(bucket_name, key, filename)

# Print a confirmation message
print(f'File {key} downloaded from bucket {bucket_name} to local file.')
# Out:
# File snowflake_logo.png downloaded from bucket ben-techcatalyst-lab to local file.

# %% [markdown]
# ### Task 6: Download a File from S3 Using get_object

# %%
# Define the file to download
bucket_name = 'ben-techcatalyst-lab'
key =  'customers.csv'

# Download the file from S3 using get_object
response = s3.get_object(
                        Bucket = bucket_name,
                        Key=key,
                        
)

#hint response['Body'].read().decode('utf-8')
content = response['Body'].read().decode('utf-8')
print(content)
# Write the content to a local file
with open('download/newfile.csv','w') as f:
    f.write(content)
f.close()

# Print a confirmation message
print(f'File {key} downloaded from bucket {bucket_name} and saved to local file.')
# Out:
# id,first_name,last_name,email,gender,ip_address
# 1,Jamal,Tonn,jtonn0@skyrock.com,Male,5.152.252.228
# 2,Karlan,Dewar,kdewar1@blogger.com,Male,112.38.93.249
# 3,Gwendolen,Nutbrown,gnutbrown2@bizjournals.com,Female,129.66.235.187
# 4,Jodee,Skentelbury,jskentelbury3@mapquest.com,Female,102.219.236.140
# 5,Kylie,Midgely,kmidgely4@wired.com,Female,51.114.34.11
# 6,Donetta,Baudone,dbaudone5@latimes.com,Female,47.154.22.249
# 7,Elsa,Faldoe,efaldoe6@wikispaces.com,Female,163.254.219.246
# 8,Marti,Davidsohn,mdavidsohn7@bizjournals.com,Female,122.246.128.60
# 9,Tristan,Siflet,tsiflet8@photobucket.com,Male,43.201.129.202
# 10,Minda,Joao,mjoao9@t.co,Female,162.109.159.176
# 11,Wrennie,Bowbrick,wbowbricka@china.com.cn,Agender,10.56.234.122
# 12,Jada,Sictornes,jsictornesb@feedburner.com,Female,252.92.201.83
# 13,Mellisa,Borsnall,mborsnallc@de.vu,Female,233.129.196.248
# 14,Elspeth,Eriksson,eerikssond@nasa.gov,Female,144.79.13.152
# 15,Rubi,Mandry,rmandrye@flavors.me,Female,226.186.250.25
# 16,Archer,Bowdler,abowdlerf@1und1.de,Male,150.228.202.36
# 17,Felix,Gaynsford,fgaynsfordg@vistaprint.com,Male,201.93.38.235
# 18,Crysta,Van Daalen,cvandaalenh@xinhuanet.com,Female,220.1.183.132
# 19,Waverley,Manvell,wmanvelli@ucsd.edu,Male,22.1.27.126
# 20,Korney,Couroy,kcouroyj@odnoklassniki.ru,Female,240.90.194.18
# 21,Tristam,Eginton,tegintonk@vinaora.com,Male,185.246.141.175
# 22,Felicio,McCord,fmccordl@behance.net,Male,234.239.66.107
# 23,Benjamin,Winger,bwingerm@privacy.gov.au,Male,49.118.59.112
# 24,Norbert,Bennison,nbennisonn@blogtalkradio.com,Male,54.8.51.7
# 25,Aurel,Guilaem,aguilaemo@fotki.com,Female,98.241.136.11
# 26,Flint,Brittan,fbrittanp@bing.com,Male,54.246.137.14
# 27,Bianka,Alvarez,balvarezq@ucsd.edu,Female,7.25.234.15
# 28,Klarika,Novic,knovicr@scribd.com,Female,98.177.225.179
# 29,Angil,Fullom,afulloms@google.it,Female,67.250.220.81
# 30,Maggie,Abrahams,mabrahamst@blogs.com,Female,137.89.80.65
# 31,Lennie,Mebs,lmebsu@moonfruit.com,Male,64.164.159.113
# 32,Trevar,Bantham,tbanthamv@acquirethisname.com,Agender,133.184.83.176
# 33,Rhetta,Coady,rcoadyw@people.com.cn,Female,124.206.172.175
